# %%
import numpy as np
import pandas as pd
import datetime as datetime
aa = pd.read_parquet("third.parquet/line_per_month.parquet")

# %%
aa['월간사용일자'] = "20" +aa["월간사용일자"] + "-01"
aa['월간사용일자'] = pd.to_datetime(aa['월간사용일자'])

# %%
a1 = aa[aa['노선명'].str.contains("1호선")]
a2 = aa[aa['노선명'].str.contains("2호선")]
a3 = aa[aa['노선명'].str.contains("3호선")]
a4 = aa[aa['노선명'].str.contains("4호선")]
a5 = aa[aa['노선명'].str.contains("5호선")]
a6 = aa[aa['노선명'].str.contains("6호선")]
a7 = aa[aa['노선명'].str.contains("7호선")]
a8 = aa[aa['노선명'].str.contains("8호선")]
a9 = aa[aa['노선명'].str.contains("9호선")]
a10 = aa[aa['노선명'].str.contains("경강선")]
a11 = aa[aa['노선명'].str.contains("경의중앙선")]
a12 = aa[aa['노선명'].str.contains("경춘선")]
a13 = aa[aa['노선명'].str.contains("공항철도")]
a14 = aa[aa['노선명'].str.contains("수인분당선")]
a15 = aa[aa['노선명'].str.contains("우이신설선")]

# %%
a1=a1.reset_index(drop=True)
a2=a2.reset_index(drop=True)
a3=a3.reset_index(drop=True)
a4=a4.reset_index(drop=True)
a5=a5.reset_index(drop=True)
a6=a6.reset_index(drop=True)
a7=a7.reset_index(drop=True)
a8=a8.reset_index(drop=True)
a9=a9.reset_index(drop=True)
a10=a10.reset_index(drop=True)
a11=a11.reset_index(drop=True)
a12=a12.reset_index(drop=True)
a13=a13.reset_index(drop=True)
a14=a14.reset_index(drop=True)
a15=a15.reset_index(drop=True)

# %%
a1.iloc[:24]["승차총승객수"].mean()
# Out:
# 40157766.333333336

# %%
def ratio1(x):
    max = a1.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a1["승차총승객수"]= a1["승차총승객수"].apply(ratio1)
def ratio2(x):
    max = a2.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a2["승차총승객수"]= a2["승차총승객수"].apply(ratio2)
def ratio3(x):
    max = a3.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a3["승차총승객수"]= a3["승차총승객수"].apply(ratio3)
def ratio4(x):
    max = a4.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a4["승차총승객수"]= a4["승차총승객수"].apply(ratio4)
def ratio5(x):
    max = a5.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a5["승차총승객수"]= a5["승차총승객수"].apply(ratio5)
def ratio6(x):
    max = a6.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a6["승차총승객수"]= a6["승차총승객수"].apply(ratio6)
def ratio7(x):
    max = a7.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a7["승차총승객수"]= a7["승차총승객수"].apply(ratio7)
def ratio8(x):
    max = a8.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a8["승차총승객수"]= a8["승차총승객수"].apply(ratio8)
def ratio9(x):
    max = a9.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a9["승차총승객수"]= a9["승차총승객수"].apply(ratio9)
def ratio10(x):
    max = a10.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a10["승차총승객수"]= a10["승차총승객수"].apply(ratio10)
def ratio11(x):
    max = a11.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a11["승차총승객수"]= a11["승차총승객수"].apply(ratio11)
def ratio12(x):
    max = a12.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a12["승차총승객수"]= a12["승차총승객수"].apply(ratio12)
def ratio13(x):
    max = a13.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a13["승차총승객수"]= a13["승차총승객수"].apply(ratio13)
def ratio14(x):
    max = a14.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a14["승차총승객수"]= a14["승차총승객수"].apply(ratio14)
def ratio15(x):
    max = a15.iloc[:24]["승차총승객수"].mean()
    a = x-max
    return (a/max)*100
a15["승차총승객수"]= a15["승차총승객수"].apply(ratio15)

# %%
a2
# Out:
#        월간사용일자  노선명     승차총승객수
# 0  2018-01-01  2호선  -1.283369
# 1  2018-02-01  2호선 -13.428586
# 2  2018-03-01  2호선   5.484191
# 3  2018-04-01  2호선   1.698652
# 4  2018-05-01  2호선   3.798201
# 5  2018-06-01  2호선  -2.147587
# 6  2018-07-01  2호선   1.877941
# 7  2018-08-01  2호선  -1.878861
# 8  2018-09-01  2호선  -8.340022
# 9  2018-10-01  2호선   4.000334
# 10 2018-11-01  2호선   3.976435
# 11 2018-12-01  2호선   2.624223
# 12 2019-01-01  2호선   0.894891
# 13 2019-02-01  2호선 -14.633740
# 14 2019-03-01  2호선   3.368211
# 15 2019-04-01  2호선   3.462708
# 16 2019-05-01  2호선   6.179857
# 17 2019-06-01  2호선  -2.653309
# 18 2019-07-01  2호선   3.691416
# 19 2019-08-01  2호선  -1.322666
# 20 2019-09-01  2호선  -7.022354
# 21 2019-10-01  2호선   4.980689
# 22 2019-11-01  2호선   2.033818
# 23 2019-12-01  2호선   4.638926
# 24 2020-01-01  2호선  -7.544802
# 25 2020-02-01  2호선 -23.516602
# 26 2020-03-01  2호선 -38.009500
# 27 2020-04-01  2호선 -34.578342
# 28 2020-05-01  2호선 -29.029427
# 29 2020-06-01  2호선 -25.579158
# ...

# %%
a1.rename(columns = {'승차총승객수' : '1호선'}, inplace = True)
a2.rename(columns = {'승차총승객수' : '2호선'}, inplace = True)
a3.rename(columns = {'승차총승객수' : '3호선'}, inplace = True)
a4.rename(columns = {'승차총승객수' : '4호선'}, inplace = True)
a5.rename(columns = {'승차총승객수' : '5호선'}, inplace = True)
a6.rename(columns = {'승차총승객수' : '6호선'}, inplace = True)
a7.rename(columns = {'승차총승객수' : '7호선'}, inplace = True)
a8.rename(columns = {'승차총승객수' : '8호선'}, inplace = True)
a9.rename(columns = {'승차총승객수' : '9호선'}, inplace = True)
a10.rename(columns = {'승차총승객수' : '경강선'}, inplace = True)
a11.rename(columns = {'승차총승객수' : '경의중앙선'}, inplace = True)
a12.rename(columns = {'승차총승객수' : '경춘선'}, inplace = True)
a13.rename(columns = {'승차총승객수' : '공항철도'}, inplace = True)
a14.rename(columns = {'승차총승객수' : '수인분당선'}, inplace = True)
a15.rename(columns = {'승차총승객수' : '우이신설선'}, inplace = True)

# %%
result = pd.concat([a1['월간사용일자'].reset_index(drop=True),
                   a1['1호선'].reset_index(drop=True),
                   a2['2호선'].reset_index(drop=True),
                    a3['3호선'].reset_index(drop=True),
                   a4['4호선'].reset_index(drop=True),
                   a5['5호선'].reset_index(drop=True),
                   a6['6호선'].reset_index(drop=True),
                   a7['7호선'].reset_index(drop=True),
                   a8['8호선'].reset_index(drop=True),
                   a9['9호선'].reset_index(drop=True),
                   a10['경강선'].reset_index(drop=True),                   
                   ],

                    axis=1,)
result = pd.concat([result,
                   a11['경의중앙선'].reset_index(drop=True),
                   a12['경춘선'].reset_index(drop=True),
                   a13['공항철도'].reset_index(drop=True),
                   a14['수인분당선'].reset_index(drop=True),
                   a15['우이신설선'].reset_index(drop=True)
                   ], axis = 1)
result
# Out:
#        월간사용일자        1호선        2호선        3호선        4호선        5호선  \
# 0  2018-01-01  -6.073319  -1.283369  -4.216047  -4.504996  -2.783064
# 1  2018-02-01 -15.332731 -13.428586 -14.970832 -15.583282 -15.378458
# 2  2018-03-01   6.856566   5.484191   4.337078   7.339130   4.962813
# 3  2018-04-01   3.511225   1.698652   1.302796   4.662990   3.498236
# 4  2018-05-01   7.130134   3.798201   4.717758   7.828543   5.088374
# 5  2018-06-01  -0.797027  -2.147587  -2.421004  -0.156641  -1.731083
# 6  2018-07-01  -3.013498   1.877941  -0.290935  -1.907538  -0.302688
# 7  2018-08-01  -5.958995  -1.878861  -3.498843  -5.870514  -3.990837
# 8  2018-09-01  -3.840247  -8.340022  -6.513402  -6.266705  -8.173079
# 9  2018-10-01   6.717238   4.000334   4.972150   6.463834   5.154029
# 10 2018-11-01   4.371644   3.976435   4.332328   4.585143   4.262286
# 11 2018-12-01   1.312161   2.624223   1.614140   2.352315   0.832611
# 12 2019-01-01  -2.962541   0.894891  -0.684174  -2.936533  -0.251335
# ...

# %%
result.to_csv("third.parquet/result-1.csv")
