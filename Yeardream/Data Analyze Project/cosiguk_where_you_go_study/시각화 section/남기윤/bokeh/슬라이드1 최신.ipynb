# %%
import numpy as np
import pandas as pd
import datetime as datetime
aa = pd.read_parquet("third.parquet")
aa
# Out:
#     월간사용일자    노선명    승차총승객수
# 0    18-01    1호선  37718857
# 1    18-01    2호선  45887286
# 2    18-01    3호선  19761386
# 3    18-01    4호선  23688734
# 4    18-01    5호선  17821981
# ..     ...    ...       ...
# 670  21-09  경의중앙선   4760404
# 671  21-09    경춘선    984883
# 672  21-09   공항철도   2214767
# 673  21-09  수인분당선   9574471
# 674  21-09  우이신설선   1074789
#
# [675 rows x 3 columns]

# %%
aa['월간사용일자'] = aa["월간사용일자"] + "-01"
aa
# Out:
#        월간사용일자    노선명    승차총승객수
# 0    18-01-01    1호선  37718857
# 1    18-01-01    2호선  45887286
# 2    18-01-01    3호선  19761386
# 3    18-01-01    4호선  23688734
# 4    18-01-01    5호선  17821981
# ..        ...    ...       ...
# 670  21-09-01  경의중앙선   4760404
# 671  21-09-01    경춘선    984883
# 672  21-09-01   공항철도   2214767
# 673  21-09-01  수인분당선   9574471
# 674  21-09-01  우이신설선   1074789
#
# [675 rows x 3 columns]

# %%
aa['월간사용일자'] ="20"+ aa["월간사용일자"]
aa
# Out:
#          월간사용일자    노선명    승차총승객수
# 0    2018-01-01    1호선  37718857
# 1    2018-01-01    2호선  45887286
# 2    2018-01-01    3호선  19761386
# 3    2018-01-01    4호선  23688734
# 4    2018-01-01    5호선  17821981
# ..          ...    ...       ...
# 670  2021-09-01  경의중앙선   4760404
# 671  2021-09-01    경춘선    984883
# 672  2021-09-01   공항철도   2214767
# 673  2021-09-01  수인분당선   9574471
# 674  2021-09-01  우이신설선   1074789
#
# [675 rows x 3 columns]

# %%
aa['월간사용일자'] = pd.to_datetime(aa['월간사용일자'])
aa
# Out:
#         월간사용일자    노선명    승차총승객수
# 0   2018-01-01    1호선  37718857
# 1   2018-01-01    2호선  45887286
# 2   2018-01-01    3호선  19761386
# 3   2018-01-01    4호선  23688734
# 4   2018-01-01    5호선  17821981
# ..         ...    ...       ...
# 670 2021-09-01  경의중앙선   4760404
# 671 2021-09-01    경춘선    984883
# 672 2021-09-01   공항철도   2214767
# 673 2021-09-01  수인분당선   9574471
# 674 2021-09-01  우이신설선   1074789
#
# [675 rows x 3 columns]

# %%
a1 = aa[aa['노선명'].str.contains("1호선")]
a2 = aa[aa['노선명'].str.contains("2호선")]
a3 = aa[aa['노선명'].str.contains("3호선")]
a4 = aa[aa['노선명'].str.contains("4호선")]
a5 = aa[aa['노선명'].str.contains("5호선")]
a6 = aa[aa['노선명'].str.contains("6호선")]
a7 = aa[aa['노선명'].str.contains("7호선")]
a8 = aa[aa['노선명'].str.contains("8호선")]
a9 = aa[aa['노선명'].str.contains("9호선")]
a10 = aa[aa['노선명'].str.contains("경강선")]
a11 = aa[aa['노선명'].str.contains("경의중앙선")]
a12 = aa[aa['노선명'].str.contains("경춘선")]
a13 = aa[aa['노선명'].str.contains("공항철도")]
a14 = aa[aa['노선명'].str.contains("수인분당선")]
a15 = aa[aa['노선명'].str.contains("우이신설선")]

# %%
def ratio1(x):
    max = a1.max()[2]
    a = x-max
    return (a/max)*100
a1["승차총승객수"]= a1["승차총승객수"].apply(ratio1)
def ratio2(x):
    max = a2.max()[2]
    a = x-max
    return (a/max)*100
a2["승차총승객수"]= a2["승차총승객수"].apply(ratio2)
def ratio3(x):
    max = a3.max()[2]
    a = x-max
    return (a/max)*100
a3["승차총승객수"]= a3["승차총승객수"].apply(ratio3)
def ratio4(x):
    max = a4.max()[2]
    a = x-max
    return (a/max)*100
a4["승차총승객수"]= a4["승차총승객수"].apply(ratio4)
def ratio5(x):
    max = a5.max()[2]
    a = x-max
    return (a/max)*100
a5["승차총승객수"]= a5["승차총승객수"].apply(ratio5)
def ratio6(x):
    max = a6.max()[2]
    a = x-max
    return (a/max)*100
a6["승차총승객수"]= a6["승차총승객수"].apply(ratio6)
def ratio7(x):
    max = a7.max()[2]
    a = x-max
    return (a/max)*100
a7["승차총승객수"]= a7["승차총승객수"].apply(ratio7)
def ratio8(x):
    max = a8.max()[2]
    a = x-max
    return (a/max)*100
a8["승차총승객수"]= a8["승차총승객수"].apply(ratio8)
def ratio9(x):
    max = a9.max()[2]
    a = x-max
    return (a/max)*100
a9["승차총승객수"]= a9["승차총승객수"].apply(ratio9)
def ratio10(x):
    max = a10.max()[2]
    a = x-max
    return (a/max)*100
a10["승차총승객수"]= a10["승차총승객수"].apply(ratio10)
def ratio11(x):
    max = a11.max()[2]
    a = x-max
    return (a/max)*100
a11["승차총승객수"]= a11["승차총승객수"].apply(ratio11)
def ratio12(x):
    max = a12.max()[2]
    a = x-max
    return (a/max)*100
a12["승차총승객수"]= a12["승차총승객수"].apply(ratio12)
def ratio13(x):
    max = a13.max()[2]
    a = x-max
    return (a/max)*100
a13["승차총승객수"]= a13["승차총승객수"].apply(ratio13)
def ratio14(x):
    max = a14.max()[2]
    a = x-max
    return (a/max)*100
a14["승차총승객수"]= a14["승차총승객수"].apply(ratio14)
def ratio15(x):
    max = a15.max()[2]
    a = x-max
    return (a/max)*100
a15["승차총승객수"]= a15["승차총승객수"].apply(ratio15)
# Out:
# <ipython-input-23-3d41334ddb68>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a1["승차총승객수"]= a1["승차총승객수"].apply(ratio1)
# <ipython-input-23-3d41334ddb68>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2["승차총승객수"]= a2["승차총승객수"].apply(ratio2)
# <ipython-input-23-3d41334ddb68>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
a1.to_csv("third.parquet/a1.csv")
a2.to_csv("third.parquet/a2.csv")
a3.to_csv("third.parquet/a3.csv")
a4.to_csv("third.parquet/a4.csv")
a5.to_csv("third.parquet/a5.csv")
a6.to_csv("third.parquet/a6.csv")
a7.to_csv("third.parquet/a7.csv")
a8.to_csv("third.parquet/a8.csv")
a9.to_csv("third.parquet/a9.csv")
a10.to_csv("third.parquet/a10.csv")
a11.to_csv("third.parquet/a11.csv")
a12.to_csv("third.parquet/a12.csv")
a13.to_csv("third.parquet/a13.csv")
a14.to_csv("third.parquet/a14.csv")
a15.to_csv("third.parquet/a15.csv")

# %%
from bokeh.layouts import gridplot
from bokeh.palettes import Spectral4 #4가지 선그래프 사용가능한 고정폼
from bokeh.plotting import figure, show, output_file,save
from bokeh.io import output_notebook, curdoc
from bokeh.models import Arc, ColumnDataSource, Grid, LinearAxis, Plot,LogAxis,Range1d,BoxAnnotation,RangeSlider
from bokeh.themes import Theme
from bokeh.core.properties import Bool, Float, Tuple

# %%
p = figure
output_notebook()
p = figure(width=800, height=500, x_axis_type="datetime")
p.title.text = '노선별 퍼센티지 변화'
p.line(a1['월간사용일자'],a1['승차총승객수'],line_width=2,color="blue",alpha=1, muted_color="red", legend_label="1호선")
p.line(a2['월간사용일자'], a2['승차총승객수'], line_width=2, color="red",alpha=1, muted_color="red", legend_label="2호선")
p.line(a3['월간사용일자'], a3['승차총승객수'], line_width=2, color="orange",alpha=1, muted_color="red", legend_label="3호선")
p.line(a4['월간사용일자'], a4['승차총승객수'], line_width=2, color="green",alpha=1, muted_color="red", legend_label="4호선")
p.line(a5['월간사용일자'], a5['승차총승객수'], line_width=2, color="yellow",alpha=1, muted_color="red", legend_label="5호선")
p.line(a6['월간사용일자'], a6['승차총승객수'], line_width=2, color="purple",alpha=1, muted_color="red", legend_label="6호선")
p.line(a7['월간사용일자'], a7['승차총승객수'], line_width=2, color="brown",alpha=1, muted_color="red", legend_label="7호선")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2487">Loading BokehJS ...</span>
#     </div>
# GlyphRenderer(id='2735', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="d7d8571f-c057-4a4e-bb3c-1c19ba9a02b0" data-root-id="2488"></div>

# %%
p.line(a6['월간사용일자'], a6['승차총승객수'], line_width=2, color="purple",alpha=0.5, muted_color="red", legend_label="6호선")
p.line(a7['월간사용일자'], a7['승차총승객수'], line_width=2, color="brown",alpha=0.5, muted_color="red", legend_label="7호선")
p.line(a8['월간사용일자'], a8['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="8호선")
p.line(a9['월간사용일자'], a9['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="9호선")
p.line(a10['월간사용일자'], a10['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="경강선")
p.line(a11['월간사용일자'], a11['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="경의중앙선")
p.line(a12['월간사용일자'], a12['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="경춘선")
p.line(a13['월간사용일자'], a13['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="공항철도")
p.line(a14['월간사용일자'], a14['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="수인분당선")
p.line(a15['월간사용일자'], a15['승차총승객수'], line_width=2, color="red",alpha=0.5, muted_color="red", legend_label="우이신설선")
# Out:
# GlyphRenderer(id='6184', ...)
